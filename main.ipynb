# %%
import drawBot as db
import re
from datetime import date
import nltk
from newspaper import Article
import argparse
import sys

def drawing(titlestring):
    # from drawBot i
    # mport roundedRect
    db.newDrawing()
    db.newPage(5000, 5000)
    db.language('English')
    db.fill(1)
    db.rect(0, 0, 5000, 5000) # White canvas
    db.fill(0)
    db.rect(125, 125, 4750, 4750) # Black smaller canvas
    db.font('Termina')
    db.fontSize(270)
    db.fill(1)
    db.rect(330, 4550, 4340, 40) #top rectangle
    db.rect(1000, 450, 3670, 40) #bottom rectangle
    db.fill(0.12)
    db.rect(330, 2750, 4340, 1700) #title background
    db.fill(0.4)
    db.rect(330, 2500, 3730, 140) # 1st context box
    db.rect(330, 2300, 3030, 140) # 2nd context box
    db.rect(330, 2100, 2330, 140) # 3rd context box
    db.rect(330, 1900, 1630, 140) # 4th context box
    db.fill(1)
    titleBox = (450, 1200, 4100, 3130)
    # db.rect(*titleBox)
    # db.hyphenation(True)
    db.lineHeight(285)


    def convert_to_uupercase(m):
        """Convert the second group to uppercase and join both group 1 & group 2"""
        return m.group(1) + m.group(2).upper()
    titleText = titlestring
    titleText = re.sub("(^|\s)(\S)", convert_to_uupercase, titleText)


    db.textBox(titleText, titleBox, align='left')
    im = db.ImageObject()
    w, h = db.imageSize('logo.png')
    with db.savedState():
        db.scale(0.45, 0.45)
        db.image('logo.png', (550, 250))

    db.fontSize(85)
    dateBox = (1000,4510,3670,420)
    db.textBox(date.today().strftime("%m/%d/%y"), dateBox, align='right')

    hastagBox = (1000,150,3670,420)
    db.textBox('@ukeconomiccircle    #StandWithHongKong', hastagBox, align='right')
    db.saveImage(f"{date.today().strftime('%m_%d_%y')}.jpg")
    db.endDrawing()

def summary(url):
    article = Article(url)
    article.download()
    article.parse()
    article.nlp()
    title = article.title
    news_summary = article.summary
    keywords = article.keywords
    return title, news_summary, keywords

def main(url):
    title, news_summary, keywords =summary(url)
    print('【'+title+'】')
    print(news_summary)
    keywords = keywords+['FightForFreedom','StandWithHongKong','ukeconomiccircle','英國經濟圈']
    for keyword in keywords:
        print('#'+keyword)
    drawing(title)

if __name__ == '__main__':
    # parser = argparse.ArgumentParser(description = 'Auto Graphic Design with Article Summary')
    # parser.add_argument('--folder', help = "Subfolder of C:\TEMP\ to manipulate")
    # args = parser.parse_args()
    url = str(sys.argv[1])
    main(url)
# Out:
# 【Covid booster shots significantly strengthen immunity, trial finds】
# Covid booster shots can dramatically strengthen the body’s immune defences, according to a study that raises hopes of preventing another wave of severe disease driven by the Omicron variant.
# Those boosted with Pfizer after two doses of AstraZeneca had antibody levels a month later nearly 25 times higher than controls.
# When the Pfizer booster was given following two Pfizer shots, antibody levels rose more than eightfold.
# The study found AstraZeneca to be an effective booster too, raising antibody levels three and five times after primary vaccination with AstraZeneca and Pfizer respectively.
# Further results from the study suggest that booster programmes could switch to half-doses of the Pfizer vaccine without losing much protection.
# #covid
# #astrazeneca
# #shots
# #study
# #boosters
# #pfizer
# #strengthen
# #finds
# #vaccine
# #booster
# #scientists
# #times
# #significantly
# #immunity
# #levels
# #antibody
# #trial

# %%
# title, summary = summary('')
# url = 
# article = Article(url)
# article.download()
# article.parse()
# article.nlp()
# print(article.title)

# print(article.summary)

# article.top_image
# Out:
# Covid booster shots significantly strengthen immunity, trial finds
# Covid booster shots can dramatically strengthen the body’s immune defences, according to a study that raises hopes of preventing another wave of severe disease driven by the Omicron variant.
# Those boosted with Pfizer after two doses of AstraZeneca had antibody levels a month later nearly 25 times higher than controls.
# When the Pfizer booster was given following two Pfizer shots, antibody levels rose more than eightfold.
# The study found AstraZeneca to be an effective booster too, raising antibody levels three and five times after primary vaccination with AstraZeneca and Pfizer respectively.
# Further results from the study suggest that booster programmes could switch to half-doses of the Pfizer vaccine without losing much protection.

# %%
myText = open('file_name.txt','a')
myString = 'Type your string here'
myText.write(myString+'\n')
myText.close()

# %%
a_file = open("file_name.txt", "r")
lines = a_file.readlines()[1].replace('\n','')
a_file.close()
lines
# Out:
# 'Type your string here'

# %%
import text_manipulate

text_manipulate.add_entry('hello')

# %%
new_file = open("file_name.txt", "w")
print(lines)
for line in lines:
    if line.strip("\n") != lines+'\n':
        new_file.write(line)

new_file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/vb/f_g_fxns7b9f60j19824s81w0000gn/T/ipykernel_3140/4144009761.py in <module>
#       1 new_file = open("file_name.txt", "w")
# ----> 2 print(lines)
#       3 for line in lines:
#       4     if line.strip("\n") != lines+'\n':
#       5         new_file.write(line)
#
# NameError: name 'lines' is not defined

# %%
for eachFontName in drawBot.installedFonts(supportsCharacters='ЉДЖ'):
    print(eachFontName)
# Out:
# AmericanTypewriter
# AmericanTypewriter-Light
# AmericanTypewriter-Semibold
# AmericanTypewriter-Bold
# AmericanTypewriter-Condensed
# AmericanTypewriter-CondensedLight
# AmericanTypewriter-CondensedBold
# AndaleMono
# ArialMT
# Arial-ItalicMT
# Arial-BoldMT
# Arial-BoldItalicMT
# Arial-Black
# ArialNarrow
# ArialNarrow-Italic
# ArialNarrow-Bold
# ArialNarrow-BoldItalic
# ArialUnicodeMS
# Avenir-Heavy
# AvenirNext-Regular
# AvenirNext-Medium
# AvenirNext-Italic
# AvenirNext-MediumItalic
# AvenirNext-DemiBold
# AvenirNext-Bold
# AvenirNext-DemiBoldItalic
# AvenirNext-BoldItalic
# AvenirNextCondensed-DemiBold
# Ayuthaya
# Baskerville
# Baskerville-Italic
# Baskerville-SemiBold
# Baskerville-Bold
# Baskerville-SemiBoldItalic
# Baskerville-BoldItalic
# BradleyHandITCTT-Bold
# BrushScriptMT
# Captureit
# ChalkboardSE-Regular
# ChalkboardSE-Light
# ChalkboardSE-Bold
# Charter-Roman
# Charter-Italic
# Charter-Bold
# Charter-BoldItalic
# Cochin
# Cochin-Italic
# Cochin-Bold
# Cochin-BoldItalic
# ComicSansMS
# ComicSansMS-Bold
# Copperplate
# Copperplate-Light
# Copperplate-Bold
# Corporate-Logo-Rounded
# CourierNewPSMT
# CourierNewPS-ItalicMT
# CourierNewPS-BoldMT
# CourierNewPS-BoldItalicMT
# CP-Font
# Didot-Bold
# DINAlternate-Bold
# DINCondensed-Bold
# FiraCodeNerdFontComplete-Medium
# TsukuAOldMinPr6N-L
# Free-HK-Kai-4700
# Futura-Bold
# GenJyuuGothic-Regular
# GenJyuuGothic-Medium
# GenJyuuGothic-Normal
# GenJyuuGothic-Light
# GenJyuuGothic-ExtraLight
# GenJyuuGothic-Bold
# GenJyuuGothic-Heavy
# GenJyuuGothicL-Monospace-Regular
# GenJyuuGothicL-Monospace-Normal
# GenJyuuGothicL-Monospace-Medium
# GenJyuuGothicL-Monospace-Light
# GenJyuuGothicL-Monospace-ExtraLight
# GenJyuuGothicL-Monospace-Bold
# GenJyuuGothicL-Monospace-Heavy
# GenJyuuGothicL-P-Regular
# GenJyuuGothicL-P-Medium
# GenJyuuGothicL-P-Normal
# GenJyuuGothicL-P-Light
# GenJyuuGothicL-P-ExtraLight
# GenJyuuGothicL-P-Bold
# GenJyuuGothicL-P-Heavy
# GenJyuuGothic-Monospace-Regular
# GenJyuuGothic-Monospace-Normal
# GenJyuuGothic-Monospace-Medium
# GenJyuuGothic-Monospace-Light
# GenJyuuGothic-Monospace-ExtraLight
# GenJyuuGothic-Monospace-Bold
# GenJyuuGothic-Monospace-Heavy
# GenJyuuGothic-P-Regular
# GenJyuuGothic-P-Medium
# GenJyuuGothic-P-Normal
# GenJyuuGothic-P-Light
# GenJyuuGothic-P-ExtraLight
# GenJyuuGothic-P-Bold
# GenJyuuGothic-P-Heavy
# GenJyuuGothicX-Monospace-Regular
# GenJyuuGothicX-Monospace-Normal
# GenJyuuGothicX-Monospace-Medium
# GenJyuuGothicX-Monospace-Light
# GenJyuuGothicX-Monospace-ExtraLight
# GenJyuuGothicX-Monospace-Bold
# GenJyuuGothicX-Monospace-Heavy
# GenJyuuGothicX-P-Regular
# GenJyuuGothicX-P-Medium
# GenJyuuGothicX-P-Normal
# GenJyuuGothicX-P-Light
# GenJyuuGothicX-P-ExtraLight
# GenJyuuGothicX-P-Bold
# GenJyuuGothicX-P-Heavy
# GenJyuuGothicL-Regular
# GenJyuuGothicL-Medium
# GenJyuuGothicL-Normal
# GenJyuuGothicL-Light
# GenJyuuGothicL-ExtraLight
# GenJyuuGothicL-Bold
# GenJyuuGothicL-Heavy
# GenJyuuGothicX-Regular
# GenJyuuGothicX-Medium
# GenJyuuGothicX-Normal
# GenJyuuGothicX-Light
# GenJyuuGothicX-ExtraLight
# GenJyuuGothicX-Bold
# GenJyuuGothicX-Heavy
# Geneva
# Georgia
# Georgia-Italic
# Georgia-Bold
# Georgia-BoldItalic
# GillSans
# GillSans-Light
# GillSans-Italic
# GillSans-LightItalic
# GillSans-SemiBold
# GillSans-Bold
# GillSans-UltraBold
# GillSans-SemiBoldItalic
# GillSans-BoldItalic
# GN-Kin-iro_SansSerif
# STHeitiSC-Light
# STHeitiSC-Medium
# STHeitiTC-Light
# STHeitiTC-Medium
# Helvetica
# Helvetica-Light
# Helvetica-Oblique
# Helvetica-LightOblique
# Helvetica-Bold
# Helvetica-BoldOblique
# HelveticaNeue
# HelveticaNeue-Medium
# HelveticaNeue-Light
# HelveticaNeue-Thin
# HelveticaNeue-UltraLight
# HelveticaNeue-Italic
# HelveticaNeue-MediumItalic
# HelveticaNeue-LightItalic
# HelveticaNeue-ThinItalic
# HelveticaNeue-UltraLightItalic
# HelveticaNeue-Bold
# HelveticaNeue-BoldItalic
# HelveticaNeue-CondensedBold
# HelveticaNeue-CondensedBlack
# HoeflerText-Regular
# HoeflerText-Italic
# HoeflerText-Black
# HoeflerText-BlackItalic
# Impact
# KAWAIITEGAKIMOJI
# Konatu
# Konatu-Tohaba
# LemonTuesday
# LucidaGrande
# LucidaGrande-Bold
# Luminari-Regular
# MarkerFelt-Thin
# MarkerFelt-Wide
# Menlo-Regular
# Menlo-Italic
# Menlo-Bold
# Menlo-BoldItalic
# MicrosoftSansSerif
# Monaco
# Noteworthy-Light
# Noteworthy-Bold
# Palatino-Roman
# Palatino-Italic
# Palatino-Bold
# Palatino-BoldItalic
# Phosphate-Inline
# Phosphate-Solid
# PTMono-Regular
# PTMono-Bold
# PTSans-Regular
# PTSans-Italic
# PTSans-Bold
# PTSans-BoldItalic
# PTSans-Caption
# PTSans-CaptionBold
# PTSans-Narrow
# PTSans-NarrowBold
# PTSerif-Regular
# PTSerif-Italic
# PTSerif-Bold
# PTSerif-BoldItalic
# PTSerif-Caption
# PTSerif-CaptionItalic
# Rockwell-Regular
# Rockwell-Italic
# Rockwell-Bold
# Rockwell-BoldItalic
# rounded-l-mplus-1c-regular
# rounded-l-mplus-1c-medium
# rounded-l-mplus-1c-light
# rounded-l-mplus-1c-thin
# rounded-l-mplus-1c-bold
# rounded-l-mplus-1c-heavy
# rounded-l-mplus-1c-black
# rounded-l-mplus-1m-regular
# rounded-l-mplus-1m-medium
# rounded-l-mplus-1m-light
# rounded-l-mplus-1m-thin
# rounded-l-mplus-1m-bold
# rounded-l-mplus-1mn-regular
# rounded-l-mplus-1mn-medium
# rounded-l-mplus-1mn-light
# rounded-l-mplus-1mn-thin
# rounded-l-mplus-1mn-bold
# rounded-l-mplus-1p-regular
# rounded-l-mplus-1p-medium
# rounded-l-mplus-1p-light
# rounded-l-mplus-1p-thin
# rounded-l-mplus-1p-bold
# rounded-l-mplus-1p-heavy
# rounded-l-mplus-1p-black
# rounded-l-mplus-2c-regular
# rounded-l-mplus-2c-medium
# rounded-l-mplus-2c-light
# rounded-l-mplus-2c-thin
# rounded-l-mplus-2c-bold
# rounded-l-mplus-2c-heavy
# rounded-l-mplus-2c-black
# rounded-l-mplus-2m-regular
# rounded-l-mplus-2m-medium
# rounded-l-mplus-2m-light
# rounded-l-mplus-2m-thin
# rounded-l-mplus-2m-bold
# rounded-l-mplus-2p-regular
# rounded-l-mplus-2p-medium
# rounded-l-mplus-2p-light
# rounded-l-mplus-2p-thin
# rounded-l-mplus-2p-bold
# rounded-l-mplus-2p-heavy
# rounded-l-mplus-2p-black
# rounded-x-mplus-1c-regular
# rounded-x-mplus-1c-medium
# rounded-x-mplus-1c-light
# rounded-x-mplus-1c-bold
# rounded-x-mplus-1c-heavy
# rounded-x-mplus-1c-black
# rounded-x-mplus-1m-regular
# rounded-x-mplus-1m-medium
# rounded-x-mplus-1m-light
# rounded-x-mplus-1m-bold
# rounded-x-mplus-1mn-regular
# rounded-x-mplus-1mn-medium
# rounded-x-mplus-1mn-light
# rounded-x-mplus-1mn-bold
# rounded-x-mplus-1p-regular
# rounded-x-mplus-1p-medium
# rounded-x-mplus-1p-light
# rounded-x-mplus-1p-bold
# rounded-x-mplus-1p-heavy
# rounded-x-mplus-1p-black
# rounded-x-mplus-2c-regular
# rounded-x-mplus-2c-medium
# rounded-x-mplus-2c-light
# rounded-x-mplus-2c-bold
# rounded-x-mplus-2c-heavy
# rounded-x-mplus-2c-black
# rounded-x-mplus-2m-regular
# rounded-x-mplus-2m-medium
# rounded-x-mplus-2m-light
# rounded-x-mplus-2m-bold
# rounded-x-mplus-2p-regular
# rounded-x-mplus-2p-medium
# rounded-x-mplus-2p-light
# rounded-x-mplus-2p-bold
# rounded-x-mplus-2p-heavy
# rounded-x-mplus-2p-black
# Sathu
# SavoyeLetPlain
# SignPainter-HouseScript
# SignPainter-HouseScriptSemibold
# SnellRoundhand
# SnellRoundhand-Bold
# SnellRoundhand-Black
# STSongti-SC-Regular
# STSongti-SC-Light
# STSongti-SC-Bold
# STSongti-TC-Regular
# STSongti-TC-Light
# STSongti-TC-Bold
# STIXGeneral-Regular
# STIXGeneral-Italic
# STIXGeneral-Bold
# STIXGeneral-BoldItalic
# STSong
# Tahoma
# Tahoma-Bold
# Thonburi
# Thonburi-Light
# Thonburi-Bold
# Times-Roman
# Times-Italic
# Times-Bold
# Times-BoldItalic
# TimesNewRomanPSMT
# TimesNewRomanPS-ItalicMT
# TimesNewRomanPS-BoldMT
# TimesNewRomanPS-BoldItalicMT
# Trattatello
# TrebuchetMS
# TrebuchetMS-Italic
# TrebuchetMS-Bold
# Trebuchet-BoldItalic
# Verdana
# Verdana-Italic
# Verdana-Bold
# Verdana-BoldItalic
